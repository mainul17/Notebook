# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mainul Islam Rayhan**<br>
# Data Scientist

# %% [markdown]
# *I am interested in data science because i enjoy being a part of new technologies and trying out innovative solutions. I'm especially interested in artificial intelligence after learning about machine learning in my studies, and I'm eager to use AI in a more practical capacity.*

# %% [markdown]
# The folllowing code test the Sum formula

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. Number list 1
# 2. Number list 2
# 3. Number list 3
#
# - bulleting list 1
# - bulleting list 2
# - bulleting list 3
#
# ***
